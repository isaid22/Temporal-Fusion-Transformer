# %%
import pandas as pd

# %%
# Create a complete grid of dates for every ATM/Denom group
all_dates = pd.date_range(start=df['ds'].min(), end=df['ds'].max(), freq='D')
index = pd.MultiIndex.from_product([df['unique_id'].unique(), all_dates], names=['unique_id', 'ds'])

# Reindex and fill holes with 0
df_padded = df.set_index(['unique_id', 'ds']).reindex(index, fill_value=0).reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Create a complete grid of dates for every ATM/Denom group
# ----> 2 all_dates = pd.date_range(start=df['ds'].min(), end=df['ds'].max(), freq='D')
#       3 index = pd.MultiIndex.from_product([df['unique_id'].unique(), all_dates], names=['unique_id', 'ds'])
#       5 # Reindex and fill holes with 0
#
# NameError: name 'df' is not defined
